# %% [markdown]
# # Peer-graded Assignment: Capstone Project - The Battle of Neighborhoods
#
# Now that you have been equipped with the skills and the tools to use location data to explore a geographical location, over the course of two weeks, you will have the opportunity to be as creative as you want and come up with an idea to leverage the Foursquare location data to explore or compare neighborhoods or cities of your choice or to come up with a problem that you can use the Foursquare location data to solve. If you cannot think of an idea or a problem, here are some ideas to get you started:
#
# 1. In Module 3, we explored New York City and the city of Toronto and segmented and clustered their neighborhoods. Both cities are very diverse and are the financial capitals of their respective countries. One interesting idea would be to compare the neighborhoods of the two cities and determine how similar or dissimilar they are. Is New York City more like Toronto or Paris or some other multicultural city? I will leave it to you to refine this idea.
# 2. In a city of your choice, if someone is looking to open a restaurant, where would you recommend that they open it? Similarly, if a contractor is trying to start their own business, where would you recommend that they setup their office?
#
# These are just a couple of many ideas and problems that can be solved using location data in addition to other datasets. No matter what you decide to do, make sure to provide sufficient justification of why you think what you want to do or solve is important and why would a client or a group of people be interested in your project.

# %% [markdown]
# # Week 1
# ## 1.) Business Problem

# %% [markdown]
# People who rely on public transportation will often go to places that are within walking distance from busses or trains. They care not only about accessibility to and from certain areas and neighborhoods but also what businesses are accessible. My goal is to look to see what types of restaurants are within walking distance from the Port Authority bus stops in Pittsburgh, PA. Not only will I see what restaurants are within walking distance from bus stops, but we will see what bus routes have have certain cuisines (i.e. what neighborhoods have what types of cuisines). I can also examine which neighborhoods are most accessible through public transportation. I will examine which neighborhoods have the most bus routes passing through them. To do this, we just need to count how many routes run through a given neighborhood and will rank the neighborhoods accordingly.

# %% [markdown]
# ## 2.) Data

# %% [markdown]
# Regarding the data, I will require the API from Foursquare to look at the various places given different locations.
#
# From the API, I will use the explore endpoint to search near the various bus stops. I will record the various businesses and if the business is already listed from a previous bus stop, then I will include all stops that are close to that particular bus stop. Below is an example of using the Foursquare API for a 2 kilometer area in a neighborhood in Pittsburgh.
#
# ### Foursquare API example data

# %%
import json, requests
import pandas as pd

# %%
CLIENT_ID = 'UZNFARAB5RPK3VRKCEPIBJIU0YUBE4EMDMUOWL3FK2OBNLK4' # your Foursquare ID
CLIENT_SECRET = 'R3KLBEUMMU5A3FTOX4WW1SRJHKED1SQXGMSYTFXHFJ1PEXRE' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)

LIMIT=100
radius = 2000

lat, lng = 40.442540, -79.914514

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
results = requests.get(url).json()
# Out:
# Your credentails:
# CLIENT_ID: UZNFARAB5RPK3VRKCEPIBJIU0YUBE4EMDMUOWL3FK2OBNLK4
# CLIENT_SECRET:R3KLBEUMMU5A3FTOX4WW1SRJHKED1SQXGMSYTFXHFJ1PEXRE

# %%
results = results['response']['groups'][0]['items']

# %%
lst = []
for v in results:
    lst.append([(v['venue']['name'],v['venue']['categories'][0]['name'],
                 v['venue']['location']['lat'],v['venue']['location']['lng'])])
               
nearby_venues = pd.DataFrame([item for venue_list in lst for item in venue_list], 
                             columns=['Venue','Category','Venue Latitude','Venue Longitude'])

# %%
nearby_venues
# Out:
#                                   Venue                   Category  \
# 0          Five Points Artisan Bakeshop                     Bakery
# 1                               CAFE 33           Asian Restaurant
# 2                         Hidden Harbor               Cocktail Bar
# 3                 Everyday Noodles 天天見麵               Noodle House
# 4                     Point Brugge Café    New American Restaurant
# 5                             The Manor        Indie Movie Theater
# 6                Independent Brewing Co                     Bistro
# 7   Rita's Italian Ice & Frozen Custard             Ice Cream Shop
# 8                         Rose Tea Cafe       Taiwanese Restaurant
# 9                Commonplace Coffee Co.                Coffee Shop
# 10      Squirrel Hill Shopping District                   Boutique
# 11                          Waffallonia             Breakfast Spot
# 12                            Dobrá Tea                   Tea Room
# 13                   JCC Fitness Center                        Gym
# 14  The Frick Art And Historical Center                 Art Museum
# 15                      Gluuteny Bakery                     Bakery
# 16                  Turkish Kebab House         Turkish Restaurant
# 17                     Uncle Sam's Subs             Sandwich Place
# 18                        Silk Elephant            Thai Restaurant
# 19                          Mellon Park                       Park
# 20         Massage Envy - Squirrel Hill                        Spa
# 21                           Frick Park                       Park
# 22              Jewish Community Center           Spiritual Center
# 23                     Aladdin's Eatery  Middle Eastern Restaurant
# 24                 P&G's Pamela's Diner                      Diner
# 25                        Littles Shoes                 Shoe Store
# 26                 Philip Pelusi Salons             Cosmetics Shop
# 27                              Té Café                   Tea Room
# 28                   Squirrel Hill Cafe                        Bar
# 29                    Napoli's Pizzeria                Pizza Place
# ..                                  ...                        ...
# 70     Frick Park Blue Slide Playground                 Playground
# 71                              Taza 21   Mediterranean Restaurant
# 72            Artist & Craftsman Supply        Arts & Crafts Store
# 73       Pittsburgh Center for the Arts                Art Gallery
# 74                          Cafe Moulin          French Restaurant
# 75                      Fitness Factory                        Gym
# 76                         Kawaii Gifts           Toy / Game Store
# 77                Asiatique Thai Bistro            Thai Restaurant
# 78                      Prantl's Bakery                     Bakery
# 79              Social at Bakery Square    New American Restaurant
# 80        Massage Heights-Bakery Square             Massage Studio
# 81                        T-Swirl Crepe                   Creperie
# 82                             Girasole         Italian Restaurant
# 83                         Tân Lạc Viên      Vietnamese Restaurant
# 84                      Sichuan Gourmet        Szechuan Restaurant
# 85                         Green Pepper          Korean Restaurant
# 86                             The Yard                  Gastropub
# 87                          Shady Grove                        Bar
# 88                  Lululemon Athletica        Sporting Goods Shop
# 89               Jitters Cafe Shadyside                Coffee Shop
# 90                         Fujiya Raman        Japanese Restaurant
# 91                  BLICK Art Materials        Arts & Crafts Store
# 92                              Athleta              Women's Store
# 93                      Apple Shadyside          Electronics Store
# 94              Bruegger's Bagel Bakery                 Bagel Shop
# 95                         Panera Bread                     Bakery
# 96                 Murray Avenue Kosher              Grocery Store
# 97                Allegro Hearth Bakery                     Bakery
# 98          Frick Car & Carriage Museum             History Museum
# 99                    Cafe at the Frick                       Café
#
#     Venue Latitude  Venue Longitude
# 0        40.444477       -79.916964
# 1        40.437643       -79.919236
# 2        40.437673       -79.919409
# 3        40.438159       -79.920124
# 4        40.450181       -79.913901
# 5        40.437247       -79.922673
# 6        40.437791       -79.919299
# 7        40.438030       -79.919771
# 8        40.437924       -79.920080
# 9        40.438217       -79.921907
# 10       40.438060       -79.922929
# 11       40.437772       -79.922844
# 12       40.434872       -79.922770
# 13       40.437524       -79.923818
# 14       40.446479       -79.902614
# 15       40.435304       -79.922782
# 16       40.438065       -79.922234
# 17       40.437958       -79.922560
# 18       40.437651       -79.923062
# 19       40.453413       -79.916954
# 20       40.437826       -79.921443
# 21       40.431488       -79.905993
# 22       40.437591       -79.923863
# 23       40.438010       -79.919819
# 24       40.437673       -79.922982
# 25       40.437897       -79.921036
# 26       40.436530       -79.923145
# 27       40.434603       -79.922913
# 28       40.437978       -79.922880
# 29       40.434429       -79.922904
# ..             ...              ...
# 70       40.430070       -79.914955
# 71       40.436381       -79.922935
# 72       40.432701       -79.927396
# 73       40.452254       -79.920126
# 74       40.451651       -79.933433
# 75       40.458499       -79.925341
# 76       40.450978       -79.934765
# 77       40.456544       -79.914970
# 78       40.451594       -79.932863
# 79       40.456678       -79.915953
# 80       40.457216       -79.916593
# 81       40.437562       -79.923019
# 82       40.451098       -79.934791
# 83       40.433187       -79.923087
# 84       40.435808       -79.922867
# 85       40.434075       -79.923005
# 86       40.451384       -79.933988
# 87       40.450960       -79.933682
# 88       40.451317       -79.933019
# 89       40.451751       -79.932226
# 90       40.450436       -79.935342
# 91       40.451462       -79.932528
# 92       40.450788       -79.934262
# 93       40.451211       -79.933431
# 94       40.437425       -79.922721
# 95       40.456611       -79.914994
# 96       40.435466       -79.922930
# 97       40.433738       -79.922990
# 98       40.447196       -79.902081
# 99       40.447705       -79.901630
#
# [100 rows x 4 columns]

# %% [markdown]
# ### Bus stop data
#
# The other data necessary to have is the data for each bus stop. For this, we take the data for the Port Authority bus stops. This data is found at https://data.wprdc.org/dataset/port-authority-of-allegheny-county-transit-stops. Unfortunately, this data is not in a CSV format. It instead is in a DBF format. It's necessary to transform it into a CSV data format. To do so, we must import the package csv and dbfread. From there, we can output the file into a CSV and read it in.

# %%
import csv
from dbfread import DBF

def dbf_to_csv(dbf_table_pth):#Input a dbf, output a csv, same name, same path, except extension
    csv_fn = dbf_table_pth[:-4]+ ".csv" #Set the csv file name
    table = DBF(dbf_table_pth)# table variable is a DBF object
    with open(csv_fn, 'w', newline = '') as f:# create a csv file, fill it with dbf content
        writer = csv.writer(f)
        writer.writerow(table.field_names)# write the column name
        for record in table:# write the rows
            writer.writerow(list(record.values()))
    return csv_fn# return the csv name

dbf_path = 'PAAC_Stops_1611.dbf'
new_csv = dbf_to_csv(dbf_path)

stops_df = pd.read_csv(new_csv)
stops_df.head(10)
# Out:
#   InternalID                     Name  ExternalID Direction        Lat  \
# 0     S00010       10TH AVE AT ANN ST     11652.0   Inbound  40.406334
# 1     N71237  10TH AVE AT GARFIELD ST     20654.0  Outbound  40.606766
# 2     N71239    10TH AVE AT ORMOND ST     20656.0  Outbound  40.608314
# 3     N71238    10TH AVE AT SUMMIT ST     20655.0  Outbound  40.607561
# 4     S00080     12TH AVE AT AMITY ST     11650.0   Inbound  40.404325
# 5     S00090  12TH AVE AT AMITY ST FS     19384.0  Outbound  40.404339
# 6     E70002      16TH ST AT PENN AVE     18641.0   Inbound  40.448759
# 7     N71245       1ST AVE AT BOYD ST     20649.0   Inbound  40.599348
# 8     N71244       1ST AVE AT LOCK ST     20648.0   Inbound  40.600002
# 9     S00530      22ND AVE AT MAIN ST     11036.0  Outbound  40.397642
#
#         Long Time_Point NewZone  No_Rts_Ser Routes_161 Mode  Public_She  \
# 0 -79.908116         No      1A         1.0        53L  Bus  No Shelter
# 1 -79.753111         No       2         1.0        P10  Bus  No Shelter
# 2 -79.750500         No       2         1.0        P10  Bus  No Shelter
# 3 -79.751760         No       2         1.0        P10  Bus  No Shelter
# 4 -79.908139         No      1A         2.0    53, 53L  Bus  No Shelter
# 5 -79.908339         No      1A         2.0    53, 53L  Bus  No Shelter
# 6 -79.987314         No       1         1.0         54  Bus  No Shelter
# 7 -79.755460         No       2         1.0        P10  Bus  No Shelter
# 8 -79.752677         No       2         1.0        P10  Bus  No Shelter
# 9 -79.901809         No      1A         2.0    53, 53L  Bus  No Shelter
#
#   Public_Sto
# 0   Bus Stop
# 1   Bus Stop
# 2   Bus Stop
# 3   Bus Stop
# 4   Bus Stop
# 5   Bus Stop
# 6   Bus Stop
# 7   Bus Stop
# 8   Bus Stop
# 9   Bus Stop

# %%
stops_data_dict = pd.read_csv('stopsdatadictionary.csv')
stops_data_dict
# Out:
#          Field                 Description
# 0   InternalID                          ID
# 1         Name                   Stop Name
# 2   ExternalID                 External ID
# 3    Direction                   Direction
# 4          Lat     Latitude (y Coordinate)
# 5         Long    Longitude (x coordinate)
# 6   Time_Point  Is this stop a time point?
# 7      NewZone               New Fare Zone
# 8   No_Rts_Ser  Routes served by this stop
# 9   Routes_161                      Routes
# 10        Mode                        Mode
# 11  Public_She                     Shelter
# 12  Public_Sto            Stop description

# %% [markdown]
# ### Neighborhood Boundaries
#
# The neighborhood boundaries can be found in in the 'Neighborhoods_with_SNAP_Data.geojson' found on the website:
# https://data.wprdc.org/dataset/neighborhoods-with-snap-data
